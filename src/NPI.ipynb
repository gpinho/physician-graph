# %%
import pandas as pd

# %%
npi_df = pd.read_csv("https://s3-us-west-1.amazonaws.com/physician-referral-graph/npidata_pfile_20050523-20180408_withHeader.csv", nrows=100)

# %%
npi_df.head()
# Out:
#           NPI   Entity Type Code   Replacement NPI  \
# 0  1679576722                1.0               NaN
# 1  1588667638                1.0               NaN
# 2  1497758544                2.0               NaN
# 3  1306849450                1.0               NaN
# 4  1215930367                1.0               NaN
#
#    Employer Identification Number (EIN)  \
# 0                                   NaN
# 1                                   NaN
# 2                             <UNAVAIL>
# 3                                   NaN
# 4                                   NaN
#
#    Provider Organization Name (Legal Business Name)  \
# 0                                               NaN
# 1                                               NaN
# 2            CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3                                               NaN
# 4                                               NaN
#
#    Provider Last Name (Legal Name)  Provider First Name  Provider Middle Name  \
# ...

# %%
npi_df.set_index(['NPI'], inplace=True)

# %%
npi_df.head()
# Out:
#              Entity Type Code   Replacement NPI  \
# NPI
# 1679576722                1.0               NaN
# 1588667638                1.0               NaN
# 1497758544                2.0               NaN
# 1306849450                1.0               NaN
# 1215930367                1.0               NaN
#
#             Employer Identification Number (EIN)  \
# NPI
# 1679576722                                   NaN
# 1588667638                                   NaN
# 1497758544                             <UNAVAIL>
# 1306849450                                   NaN
# 1215930367                                   NaN
#
#             Provider Organization Name (Legal Business Name)  \
# NPI
# 1679576722                                               NaN
# 1588667638                                               NaN
# 1497758544            CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 1306849450                                               NaN
# ...

# %%
npi_df['Provider Business Practice Location Address Postal Code']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Provider Business Practice Location Address Postal Code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
for col in npi_df.columns:
    print(col)
# Out:
#  Entity Type Code
#  Replacement NPI
#  Employer Identification Number (EIN)
#  Provider Organization Name (Legal Business Name)
#  Provider Last Name (Legal Name)
#  Provider First Name
#  Provider Middle Name
#  Provider Name Prefix Text
#  Provider Name Suffix Text
#  Provider Credential Text
#  Provider Other Organization Name
#  Provider Other Organization Name Type Code
#  Provider Other Last Name
#  Provider Other First Name
#  Provider Other Middle Name
#  Provider Other Name Prefix Text
#  Provider Other Name Suffix Text
#  Provider Other Credential Text
#  Provider Other Last Name Type Code
#  Provider First Line Business Mailing Address
#  Provider Second Line Business Mailing Address
#  Provider Business Mailing Address City Name
#  Provider Business Mailing Address State Name
#  Provider Business Mailing Address Postal Code
#  Provider Business Mailing Address Country Code (If outside US)
#  Provider Business Mailing Address Telephone Number
# ...

# %%
npi_df.columns = npi_df.columns.str.strip()

# %%
print(npi_df.columns.str.strip())
# Out:
# Index(['Entity Type Code', 'Replacement NPI',
#        'Employer Identification Number (EIN)',
#        'Provider Organization Name (Legal Business Name)',
#        'Provider Last Name (Legal Name)', 'Provider First Name',
#        'Provider Middle Name', 'Provider Name Prefix Text',
#        'Provider Name Suffix Text', 'Provider Credential Text',
#        ...
#        'Healthcare Provider Taxonomy Group_6',
#        'Healthcare Provider Taxonomy Group_7',
#        'Healthcare Provider Taxonomy Group_8',
#        'Healthcare Provider Taxonomy Group_9',
#        'Healthcare Provider Taxonomy Group_10',
#        'Healthcare Provider Taxonomy Group_11',
#        'Healthcare Provider Taxonomy Group_12',
#        'Healthcare Provider Taxonomy Group_13',
#        'Healthcare Provider Taxonomy Group_14',
#        'Healthcare Provider Taxonomy Group_15'],
#       dtype='object', length=328)

# %%
x = pd.Series(['Entity Type Code', 'Replacement NPI',
       'Employer Identification Number (EIN)',
       'Provider Organization Name (Legal Business Name)',
       'Provider Last Name (Legal Name)', 'Provider First Name',
       'Provider Middle Name', 'Provider Name Prefix Text',
       'Provider Name Suffix Text', 'Provider Credential Text',
       'Healthcare Provider Taxonomy Group_6',
       'Healthcare Provider Taxonomy Group_7',
       'Healthcare Provider Taxonomy Group_8',
       'Healthcare Provider Taxonomy Group_9',
       'Healthcare Provider Taxonomy Group_10',
       'Healthcare Provider Taxonomy Group_11',
       'Healthcare Provider Taxonomy Group_12',
       'Healthcare Provider Taxonomy Group_13',
       'Healthcare Provider Taxonomy Group_14',
       'Healthcare Provider Taxonomy Group_15'])

# %%
x.str.strip()
# Out:
# 0                                     Entity Type Code
# 1                                      Replacement NPI
# 2                 Employer Identification Number (EIN)
# 3     Provider Organization Name (Legal Business Name)
# 4                      Provider Last Name (Legal Name)
# 5                                  Provider First Name
# 6                                 Provider Middle Name
# 7                            Provider Name Prefix Text
# 8                            Provider Name Suffix Text
# 9                             Provider Credential Text
# 10                Healthcare Provider Taxonomy Group_6
# 11                Healthcare Provider Taxonomy Group_7
# 12                Healthcare Provider Taxonomy Group_8
# 13                Healthcare Provider Taxonomy Group_9
# 14               Healthcare Provider Taxonomy Group_10
# 15               Healthcare Provider Taxonomy Group_11
# 16               Healthcare Provider Taxonomy Group_12
# ...

# %%
new_npi_df.head()
# Out:
#           NPI
# 0  1679576722
# 1  1588667638
# 2  1497758544
# 3  1306849450
# 4  1215930367

# %%
new_npi_df = pd.read_csv('../data/samples/npidata_pfile_20050523-20180408-subsample.csv', usecols=['NPI', ' Provider Organization Name (Legal Business Name)'])

# %%
new_npi_df.head()
# Out:
#           NPI  Provider Organization Name (Legal Business Name)
# 0  1679576722                                               NaN
# 1  1588667638                                               NaN
# 2  1497758544            CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 3  1306849450                                               NaN
# 4  1215930367                                               NaN

# %%
usecols=['NPI','Provider Organization Name (Legal Business Name)','Provider Business Practice Location Address City Name','Provider Business Practice Location Address State Name','Provider Business Practice Location Address Country Code (If outside US)','Provider Gender Code','Healthcare Provider Taxonomy Code_1','Is Sole Proprietor']

# %%
npi_categorical_cols = ['Provider Organization Name (Legal Business Name)','Provider Business Practice Location Address City Name','Provider Business Practice Location Address State Name','Provider Business Practice Location Address Country Code (If outside US)','Provider Gender Code','Is Sole Proprietor']

# %%
npi_usecols = ['NPI','Provider Organization Name (Legal Business Name)','Provider Business Practice Location Address City Name','Provider Business Practice Location Address State Name','Provider Business Practice Location Address Country Code (If outside US)','Provider Gender Code','Healthcare Provider Taxonomy Code_1','Is Sole Proprietor']

# %%
npi_df = pd.read_csv("https://s3-us-west-1.amazonaws.com/physician-referral-graph/npidata_pfile_20050523-20180408_withHeader.csv", index_col=['NPI'], usecols=npi_usecols)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
npi_df
# Out:
#            Provider Organization Name (Legal Business Name)  \
# NPI
# 1679576722                                              NaN
# 1588667638                                              NaN
# 1497758544           CUMBERLAND COUNTY HOSPITAL SYSTEM, INC
# 1306849450                                              NaN
# 1215930367                                              NaN
# 1023011178                                   COLLABRIA CARE
# 1932102084                                              NaN
# 1841293990                                              NaN
# 1750384806                                              NaN
# 1669475711                                              NaN
# 1578566626                                              NaN
# 1487657532                                              NaN
# 1396748448                                              NaN
# 1205839354                                              NaN
# ...

# %%
len(npi_usecols)
# Out:
# 8

# %%
npi_df['Provider Business Practice Location Address City Name'].value_counts()
# Out:
# NEW YORK            76404
# HOUSTON             53319
# BROOKLYN            51423
# CHICAGO             50568
# LOS ANGELES         48780
# MIAMI               36403
# PORTLAND            35414
# PHILADELPHIA        34557
# WASHINGTON          33053
# SAN DIEGO           32164
# LAS VEGAS           30735
# DALLAS              29718
# SEATTLE             29304
# COLUMBUS            28989
# SAN FRANCISCO       28593
# BOSTON              27982
# BALTIMORE           26878
# BRONX               26855
# PHOENIX             25934
# SAN ANTONIO         25523
# ROCHESTER           25128
# ATLANTA             22471
# SAINT LOUIS         21843
# SPRINGFIELD         21763
# PITTSBURGH          21731
# INDIANAPOLIS        20536
# CINCINNATI          20103
# JACKSONVILLE        20076
# CLEVELAND           20021
# DENVER              19434
#                     ...
# LEGGETT                 1
# TARCNTUM                1
# ALYODONES               1
# MARCOLA                 1
# ...
