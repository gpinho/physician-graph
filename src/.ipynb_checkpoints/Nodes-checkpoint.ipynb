# %%
import numpy as np
import pandas as pd
import re
import string
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk import word_tokenize, corpus         
from nltk.stem import WordNetLemmatizer
from pipeline_nodes import convert_categorical_to_dummy

# %%
specialty_cols = ['Code', 'Grouping', 'Classification', 'Specialization', 'Definition']
specialty_df = pd.read_csv('https://s3-us-west-1.amazonaws.com/physician-referral-graph/nucc_taxonomy_180.csv', dtype=str, usecols=specialty_cols)

# %%
specialty_df.replace('Definition to come...', np.nan, inplace=True)

# %%
specialty_categorical_cols = ['Grouping', 'Classification', 'Specialization']
specialty_df_dummies = convert_categorical_to_dummy(specialty_df, specialty_categorical_cols)

# %%
specialty_df_dummies.shape
# Out:
# (854, 730)

# %%
wordnet = WordNetLemmatizer()

# %%
stopwords = set(corpus.stopwords.words('english') + list(string.punctuation))

# %%
def tokenize(doc):
    '''
    INPUT: string
    OUTPUT: list of strings

    Tokenize and stem/lemmatize the document.
    '''
    return [wordnet.lemmatize(word) for word in word_tokenize(re.sub('[^a-z\s]', '', doc.lower()))]

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords, tokenizer=tokenize)

# %%
vectors = vectorizer.fit_transform(specialty_df_dummies['Definition'].fillna('')).toarray()

# %%
words = vectorizer.get_feature_names()

# %%
def get_top_values(lst, n, labels):
    '''
    INPUT: LIST, INTEGER, LIST
    OUTPUT: LIST

    Given a list of values, find the indices with the highest n values.
    Return the labels for each of these indices.

    e.g.
    lst = [7, 3, 2, 4, 1]
    n = 2
    labels = ["cat", "dog", "mouse", "pig", "rabbit"]
    output: ["cat", "pig"]
    '''
    return [labels[i] for i in np.argsort(lst)[-1:-n-1:-1]]

# %%
avg = np.sum(vectors, axis=0) / np.sum(vectors > 0, axis=0)
get_top_values(avg, 10, words)
# Out:
# ['marriage',
#  'come',
#  'coding',
#  'definition',
#  'dance',
#  'music',
#  'obesity',
#  'jx',
#  'inactive',
#  'poetry']

# %%
total = np.sum(vectors, axis=0)
get_top_values(total, 10, words)
# Out:
# ['care',
#  'patient',
#  'service',
#  'treatment',
#  'disease',
#  'individual',
#  'health',
#  'disorder',
#  'facility',
#  'medicine']

# %%
tokenized_queries = vectorizer.transform(['primary care provider', 'sickness', 'elderly', 'urgent care', 'preventive care', 'behaviour change'])
cosine_similarities = linear_kernel(tokenized_queries, vectors)
titles = specialty_df['Grouping'].astype(str) + specialty_df['Classification'].astype(str) + specialty_df['Specialization'].astype(str)

# %%
for i, definition in enumerate(['primary care provider', 'sickness', 'elderly', 'urgent care', 'preventive care', 'behaviour change']):
    print(i)
    print(definition)
    print(get_top_values(cosine_similarities[i], 3, titles))
# Out:
# 0
# primary care provider
# ['Dental ProvidersDentistGeneral Practice', 'Managed Care OrganizationsExclusive Provider Organizationnan', 'Allopathic & Osteopathic PhysiciansPediatricsNeonatal-Perinatal Medicine']
# 1
# sickness
# ['Other Service ProvidersPrevention Professionalnan', 'Allopathic & Osteopathic PhysiciansObstetrics & GynecologyHospice and Palliative Medicine', 'Allopathic & Osteopathic PhysiciansObstetrics & GynecologyFemale Pelvic Medicine and Reconstructive Surgery']
# 2
# elderly
# ['Allopathic & Osteopathic PhysiciansPsychiatry & NeurologyGeriatric Psychiatry', 'Nursing & Custodial Care FacilitiesCustodial Care FacilityAdult Care Home', 'Allopathic & Osteopathic PhysiciansInternal MedicineGeriatric Medicine']
# 3
# urgent care
# ['Hospital UnitsEpilepsy Unitnan', 'SuppliersNon-Pharmacy Dispensing Sitenan', 'Respiratory, Developmental, Rehabilitative and Restorative Service ProvidersRespiratory Therapist, RegisteredSNF/Subacute Care']
# 4
# preventive care
# ['Allopathic & Osteopathic PhysiciansPreventive MedicinePreventive Medicine/Occupational Environmental Medicine', 'Allopathic & Osteopathic PhysiciansPreventive MedicineSports Medicine', 'Dental ProvidersDentistPediatric Dentistry']
# 5
# behaviour change
# ['Respiratory, Developmental, Rehabilitative and Restorative Service ProvidersRecreation Therapistnan', 'Respiratory, Developmental, Rehabilitative and Restorative Service ProvidersOccupational TherapistDriving and Community Mobility', 'Respiratory, Developmental, Rehabilitative and Restorative Service ProvidersRespiratory Therapist, CertifiedGeriatric Care']

# %%
description_vect_df = pd.DataFrame(vectors, columns=words)

# %%
description_vect_df.columns
# Out:
# Index(['abdomen', 'abdominal', 'ability', 'ablation', 'able', 'abnormal',
#        'abnormality', 'abortion', 'abortionfamily', 'absence',
#        ...
#        'writing', 'written', 'x', 'xray', 'xrays', 'year', 'young', 'zift',
#        'zone', 'zygote'],
#       dtype='object', length=3329)

# %%
combined_df = pd.concat([specialty_df_dummies, description_vect_df], axis=1).drop(['Definition'], axis=1)

# %%
d = {}
for col in combined_df.columns:
    d[col] = combined_df[col].value_counts

# %% [markdown]
# # Let's play with Physician NPI

# %%
physician_cols = ['NPI', 'Entity Type Code', 'Provider Business Practice Location Address City Name', 'Provider Business Practice Location Address State Name', 'Provider Business Practice Location Address Country Code (If outside US)', 'Provider Gender Code', 'Healthcare Provider Taxonomy Code_1']

# %%
physician_dtype = {'NPI':int, 'Entity Type Code':float, 'Provider Business Practice Location Address City Name':str, 'Provider Business Practice Location Address State Name':str, 'Provider Business Practice Location Address Country Code (If outside US)':str, 'Provider Gender Code':str, 'Healthcare Provider Taxonomy Code_1':str}

# %%
physician_df = pd.read_csv('../data/samples/npidata_pfile_20050523-20180408_withHeader-subsample.csv', dtype=physician_dtype, usecols=physician_cols)

# %%
physician_df['Entity Type Code'].replace([1,2], ['Individual', 'Organization'], inplace=True)

# %%
physician_df
# Out:
#             NPI Entity Type Code  \
# 0    1881931285     Organization
# 1    1992931828     Organization
# 2    1508018706       Individual
# 3    1740225770       Individual
# 4    1609388560       Individual
# 5    1629571955       Individual
# 6    1356557623       Individual
# 7    1780079145       Individual
# 8    1669461463       Individual
# 9    1053710715       Individual
# 10   1710295894       Individual
# 11   1407101116       Individual
# 12   1962778076       Individual
# 13   1962622266       Individual
# 14   1104977024       Individual
# 15   1477683811       Individual
# 16   1518319235       Individual
# 17   1073843751       Individual
# 18   1609800481       Individual
# 19   1598057929       Individual
# 20   1750308607       Individual
# 21   1093887432       Individual
# 22   1750705430     Organization
# 23   1710212915       Individual
# 24   1508129057       Individual
# 25   1568443430       Individual
# 26   1932246139       Individual
# 27   1003018532       Individual
# 28   1801947338       Individual
# 29   1861468258       Individual
# ..          ...              ...
# 970  1972744092       Individual
# 971  1699168286       Individual
# 972  1346564457       Individual
# 973  1851419931     Organization
# 974  1467714493       Individual
# 975  1255542783       Individual
# 976  1154365872       Individual
# 977  1982815858       Individual
# 978  1801102686     Organization
# 979  1922519248       Individual
# 980  1740356419       Individual
# 981  1750493177       Individual
# 982  1720362569       Individual
# 983  1285976134       Individual
# 984  1396805594       Individual
# 985  1255401246       Individual
# 986  1356792659     Organization
# 987  1821361106       Individual
# 988  1225337819     Organization
# 989  1629402086     Organization
# 990  1033239751       Individual
# 991  1881786853       Individual
# 992  1790792174       Individual
# 993  1538333018       Individual
# 994  1871852749       Individual
# 995  1760632715       Individual
# 996  1124063029       Individual
# 997  1720529324       Individual
# 998  1477764355       Individual
# 999  1194754226     Organization
#
#     Provider Business Practice Location Address City Name  \
# 0                                             FRANKLIN
# 1                                            BALTIMORE
# 2                                            MANHATTAN
# 3                                         CHARLES TOWN
# 4                                              DANBURY
# 5                                  SPRINGFIELD GARDENS
# 6                                            ROYAL OAK
# 7                                             BROOKLYN
# 8                                        FT LAUDERDALE
# 9                                          GAINESVILLE
# 10                                             CONCORD
# 11                                           CHARLOTTE
# 12                                        INDIANAPOLIS
# 13                                              OXNARD
# 14                                            CORONADO
# 15                                               HIRAM
# 16                                              OXNARD
# 17                                     WEST BLOOMFIELD
# 18                                            OAK LAWN
# 19                                            MAITLAND
# 20                                             BEVERLY
# 21                                             PHOENIX
# 22                                       ELIZABETHTOWN
# 23                                               SITKA
# 24                                             ASTORIA
# 25                                             DUXBURY
# 26                                           PATCHOGUE
# 27                                          GREAT BEND
# 28                                               NILES
# 29                                        INDIANAPOLIS
# ..                                                 ...
# 970                                              OMAHA
# 971                                             MANDAN
# 972                                          LONE TREE
# 973                                            FINDLAY
# 974                                             BILOXI
# 975                                       MOUNTAIN BRK
# 976                                           EL CAJON
# 977                                             DRAPER
# 978                                        ROCKY MOUNT
# 979                                           NEW YORK
# 980                                          SAN DIEGO
# 981                                            SEBRING
# 982                                            SEATTLE
# 983                                            HIALEAH
# 984                                             POMONA
# 985                                         LOUISVILLE
# 986                                            MCALLEN
# 987                                            CHICAGO
# 988                                         LAKE WALES
# 989                                         SHREVEPORT
# 990                                     FLOWERY BRANCH
# 991                                            ROSEBUD
# 992                                                APO
# 993                                         WILMINGTON
# 994                                               YORK
# 995                                           NEW YORK
# 996                                                APO
# 997                                             CANTON
# 998                                      FRANKLIN PARK
# 999                                         TEXARAKANA
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   NC
# 1                                                   MD
# 2                                                   NY
# 3                                                   WV
# 4                                                   CT
# 5                                                   NY
# 6                                                   MI
# 7                                                   NY
# 8                                                   FL
# 9                                                   FL
# 10                                                  NH
# 11                                                  NC
# 12                                                  IN
# 13                                                  CA
# 14                                                  CA
# 15                                                  GA
# 16                                                  CA
# 17                                                  MI
# 18                                                  IL
# 19                                                  FL
# 20                                                  MA
# 21                                                  AZ
# 22                                                  KY
# 23                                                  AK
# 24                                                  NY
# 25                                                  MA
# 26                                                  NY
# 27                                                  KS
# 28                                                  IL
# 29                                                  IN
# ..                                                 ...
# 970                                                 NE
# 971                                                 ND
# 972                                                 CO
# 973                                                 OH
# 974                                                 MS
# 975                                                 AL
# 976                                                 CA
# 977                                                 UT
# 978                                                 NC
# 979                                                 NY
# 980                                                 CA
# 981                                                 FL
# 982                                                 WA
# 983                                                 FL
# 984                                                 NJ
# 985                                                 KY
# 986                                                 TX
# 987                                                 IL
# 988                                                 FL
# 989                                                 LA
# 990                                                 GA
# 991                                                 SD
# 992                                                 AP
# 993                                                 NC
# 994                                                 PA
# 995                                                 NY
# 996                                                 AE
# 997                                                 OH
# 998                                                 IL
# 999                                                 AR
#
#     Provider Business Practice Location Address Country Code (If outside US)  \
# 0                                                   US
# 1                                                   US
# 2                                                   US
# 3                                                   US
# 4                                                   US
# 5                                                   US
# 6                                                   US
# 7                                                   US
# 8                                                   US
# 9                                                   US
# 10                                                  US
# 11                                                  US
# 12                                                  US
# 13                                                  US
# 14                                                  US
# 15                                                  US
# 16                                                  US
# 17                                                  US
# 18                                                  US
# 19                                                  US
# 20                                                  US
# 21                                                  US
# 22                                                  US
# 23                                                  US
# 24                                                  US
# 25                                                  US
# 26                                                  US
# 27                                                  US
# 28                                                  US
# 29                                                  US
# ..                                                 ...
# 970                                                 US
# 971                                                 US
# 972                                                 US
# 973                                                 US
# 974                                                 US
# 975                                                 US
# 976                                                 US
# 977                                                 US
# 978                                                 US
# 979                                                 US
# 980                                                 US
# 981                                                 US
# 982                                                 US
# 983                                                 US
# 984                                                 US
# 985                                                 US
# 986                                                 US
# 987                                                 US
# 988                                                 US
# 989                                                 US
# 990                                                 US
# 991                                                 US
# 992                                                 KR
# 993                                                 US
# 994                                                 US
# 995                                                 US
# 996                                                 DE
# 997                                                 US
# 998                                                 US
# 999                                                 US
#
#     Provider Gender Code Healthcare Provider Taxonomy Code_1
# 0                    NaN                          174400000X
# 1                    NaN                          251E00000X
# 2                      F                          363AS0400X
# 3                      M                          207Q00000X
# 4                      F                          163WL0100X
# 5                      F                          163W00000X
# 6                      M                          207X00000X
# 7                      M                          390200000X
# 8                      M                          207RC0000X
# 9                      M                          183500000X
# 10                     F                          133V00000X
# 11                     F                          1041C0700X
# 12                     F                          101YA0400X
# 13                     M                          122300000X
# 14                     M                          183500000X
# 15                     F                          363LF0000X
# 16                     F                          101YA0400X
# 17                     M                          101YM0800X
# 18                     M                          207Q00000X
# 19                     F                          207P00000X
# 20                     F                          1041C0700X
# 21                     F                          101YM0800X
# 22                   NaN                          101YP2500X
# 23                     M                          282N00000X
# 24                     F                          171M00000X
# 25                     M                          363A00000X
# 26                     F                          225XP0200X
# 27                     M                          103TB0200X
# 28                     M                          1835P1200X
# 29                     M                          207RA0401X
# ..                   ...                                 ...
# 970                    F                          101YM0800X
# 971                    F                          163W00000X
# 972                    M                          1223P0221X
# 973                  NaN                          111N00000X
# 974                    F                          1041C0700X
# 975                    F                          101Y00000X
# 976                    M                          207RC0000X
# 977                    F                          104100000X
# 978                  NaN                          227900000X
# 979                    F                          235Z00000X
# 980                    M                          106H00000X
# 981                    F                          207P00000X
# 982                    F                          208D00000X
# 983                    F                          363LF0000X
# 984                    F                          363L00000X
# 985                    F                          363LP0200X
# 986                  NaN                          207Q00000X
# 987                    F                          1041C0700X
# 988                  NaN                          261QF0400X
# 989                  NaN                          291U00000X
# 990                    M                          183500000X
# 991                    M                          363A00000X
# 992                    F                          163WC1500X
# 993                    F                          2084P0800X
# 994                    F                          367500000X
# 995                    M                          2084P0800X
# 996                    F                          2255A2300X
# 997                    M                          1835P2201X
# 998                    M                          183500000X
# 999                  NaN                          251G00000X
#
# [1000 rows x 7 columns]

# %%
physician_categoricals = ['Entity Type Code', 'Provider Business Practice Location Address City Name', 'Provider Business Practice Location Address State Name', 'Provider Business Practice Location Address Country Code (If outside US)', 'Provider Gender Code']

# %%
physician_df_dummies = convert_categorical_to_dummy(physician_df, physician_categoricals)

# %%
physician_df_dummies.shape
# Out:
# (1000, 719)

# %%
city_state_country
# Out:
#     Provider Business Practice Location Address City Name  \
# 0                                             FRANKLIN
# 1                                            BALTIMORE
# 2                                            MANHATTAN
# 3                                         CHARLES TOWN
# 4                                              DANBURY
# 5                                  SPRINGFIELD GARDENS
# 6                                            ROYAL OAK
# 7                                             BROOKLYN
# 8                                        FT LAUDERDALE
# 9                                          GAINESVILLE
# 10                                             CONCORD
# 11                                           CHARLOTTE
# 12                                        INDIANAPOLIS
# 13                                              OXNARD
# 14                                            CORONADO
# 15                                               HIRAM
# 16                                              OXNARD
# 17                                     WEST BLOOMFIELD
# 18                                            OAK LAWN
# 19                                            MAITLAND
# 20                                             BEVERLY
# 21                                             PHOENIX
# 22                                       ELIZABETHTOWN
# 23                                               SITKA
# 24                                             ASTORIA
# 25                                             DUXBURY
# 26                                           PATCHOGUE
# 27                                          GREAT BEND
# 28                                               NILES
# 29                                        INDIANAPOLIS
# ..                                                 ...
# 970                                              OMAHA
# 971                                             MANDAN
# 972                                          LONE TREE
# 973                                            FINDLAY
# 974                                             BILOXI
# 975                                       MOUNTAIN BRK
# 976                                           EL CAJON
# 977                                             DRAPER
# 978                                        ROCKY MOUNT
# 979                                           NEW YORK
# 980                                          SAN DIEGO
# 981                                            SEBRING
# 982                                            SEATTLE
# 983                                            HIALEAH
# 984                                             POMONA
# 985                                         LOUISVILLE
# 986                                            MCALLEN
# 987                                            CHICAGO
# 988                                         LAKE WALES
# 989                                         SHREVEPORT
# 990                                     FLOWERY BRANCH
# 991                                            ROSEBUD
# 992                                                APO
# 993                                         WILMINGTON
# 994                                               YORK
# 995                                           NEW YORK
# 996                                                APO
# 997                                             CANTON
# 998                                      FRANKLIN PARK
# 999                                         TEXARAKANA
#
#     Provider Business Practice Location Address State Name  \
# 0                                                   NC
# 1                                                   MD
# 2                                                   NY
# 3                                                   WV
# 4                                                   CT
# 5                                                   NY
# 6                                                   MI
# 7                                                   NY
# 8                                                   FL
# 9                                                   FL
# 10                                                  NH
# 11                                                  NC
# 12                                                  IN
# 13                                                  CA
# 14                                                  CA
# 15                                                  GA
# 16                                                  CA
# 17                                                  MI
# 18                                                  IL
# 19                                                  FL
# 20                                                  MA
# 21                                                  AZ
# 22                                                  KY
# 23                                                  AK
# 24                                                  NY
# 25                                                  MA
# 26                                                  NY
# 27                                                  KS
# 28                                                  IL
# 29                                                  IN
# ..                                                 ...
# 970                                                 NE
# 971                                                 ND
# 972                                                 CO
# 973                                                 OH
# 974                                                 MS
# 975                                                 AL
# 976                                                 CA
# 977                                                 UT
# 978                                                 NC
# 979                                                 NY
# 980                                                 CA
# 981                                                 FL
# 982                                                 WA
# 983                                                 FL
# 984                                                 NJ
# 985                                                 KY
# 986                                                 TX
# 987                                                 IL
# 988                                                 FL
# 989                                                 LA
# 990                                                 GA
# 991                                                 SD
# 992                                                 AP
# 993                                                 NC
# 994                                                 PA
# 995                                                 NY
# 996                                                 AE
# 997                                                 OH
# 998                                                 IL
# 999                                                 AR
#
#     Provider Business Practice Location Address Country Code (If outside US)
# 0                                                   US
# 1                                                   US
# 2                                                   US
# 3                                                   US
# 4                                                   US
# 5                                                   US
# 6                                                   US
# 7                                                   US
# 8                                                   US
# 9                                                   US
# 10                                                  US
# 11                                                  US
# 12                                                  US
# 13                                                  US
# 14                                                  US
# 15                                                  US
# 16                                                  US
# 17                                                  US
# 18                                                  US
# 19                                                  US
# 20                                                  US
# 21                                                  US
# 22                                                  US
# 23                                                  US
# 24                                                  US
# 25                                                  US
# 26                                                  US
# 27                                                  US
# 28                                                  US
# 29                                                  US
# ..                                                 ...
# 970                                                 US
# 971                                                 US
# 972                                                 US
# 973                                                 US
# 974                                                 US
# 975                                                 US
# 976                                                 US
# 977                                                 US
# 978                                                 US
# 979                                                 US
# 980                                                 US
# 981                                                 US
# 982                                                 US
# 983                                                 US
# 984                                                 US
# 985                                                 US
# 986                                                 US
# 987                                                 US
# 988                                                 US
# 989                                                 US
# 990                                                 US
# 991                                                 US
# 992                                                 KR
# 993                                                 US
# 994                                                 US
# 995                                                 US
# 996                                                 DE
# 997                                                 US
# 998                                                 US
# 999                                                 US
#
# [1000 rows x 3 columns]

# %%
city_state_country_dummies = convert_categorical_to_dummy(city_state_country, ['Provider Business Practice Location Address City Name','Provider Business Practice Location Address State Name','Provider Business Practice Location Address Country Code (If outside US)'])

# %%
city_state_country_dummies.shape
# Out:
# (1000, 713)
