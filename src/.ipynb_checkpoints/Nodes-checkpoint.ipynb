# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from pipeline_nodes import convert_categorical_to_dummy

# %%
specialty_cols = ['Code', 'Grouping', 'Classification', 'Specialization', 'Definition']
specialty_df = pd.read_csv('https://s3-us-west-1.amazonaws.com/physician-referral-graph/nucc_taxonomy_180.csv', index_col=['Code'], dtype=str, usecols=specialty_cols)

# %%
specialty_df.replace('Definition to come...', np.nan, inplace=True)

# %%
specialty_categorical_cols = ['Grouping', 'Classification', 'Specialization']
specialty_df_dummies = convert_categorical_to_dummy(specialty_df, specialty_categorical_cols)

# %%
specialty_df_dummies.shape
# Out:
# (854, 729)

# %%
wordnet = WordNetLemmatizer()

# %%
def tokenize(doc):
    '''
    INPUT: string
    OUTPUT: list of strings

    Tokenize and stem/lemmatize the document.
    '''
    return [wordnet.lemmatize(word) for word in word_tokenize(doc.lower())]

# %%
tfidfvect = TfidfVectorizer(stop_words='english', tokenizer=tokenize)

# %%
tfidfvectorizer = tfidfvect.fit_transform(specialty_df_dummies['Definition'].fillna(' '))

# %%
tfidfvect.vocabulary_
# Out:
# {'provider': 2497,
#  'trained': 3118,
#  'educated': 1000,
#  'performance': 2258,
#  'behavior': 359,
#  'health': 1394,
#  'service': 2836,
#  'interpersonal': 1632,
#  'communication': 591,
#  'analysis': 210,
#  '.': 11,
#  'training': 3120,
#  'education': 1002,
#  'specialty': 2911,
#  'level': 1738,
#  'usually': 3212,
#  'requires': 2690,
#  'master': 1834,
#  '’': 3316,
#  's': 2763,
#  'degree': 816,
#  'clinical': 541,
#  'experience': 1162,
#  'supervision': 3013,
#  'licensure': 1745,
#  'certification': 482,
#  'psychoanalysis': 2508,
#  'comprehensive': 619,
#  ',': 8,
#  'theoretical': 3079,
#  'framework': 1277,
#  'applied': 243,
#  'treatment': 3146,
#  'process': 2450,
#  'consists': 655,
#  'intensive': 1614,
#  'verbal': 3237,
#  'therapeutic': 3081,
#  'relationship': 2655,
#  'analyst': 211,
#  'analysand': 209,
#  'aim': 171,
#  'symptom': 3038,
#  'relief': 2660,
#  'emotional': 1049,
#  'growth': 1366,
#  'personal': 2279,
#  'integration': 1608,
#  'psychoanalytic': 2509,
#  'includes': 1530,
#  'limited': 1760,
#  'recognition': 2581,
#  'unconscious': 3173,
#  'conflict': 639,
#  ';': 40,
#  'significance': 2863,
#  'developmental': 868,
#  'influence': 1559,
#  'impact': 1504,
#  'resistance': 2701,
#  'defense': 809,
#  'transference': 3124,
#  'countertransference': 724,
#  'phenomenon': 2297,
#  'enhanced': 1087,
#  'understanding': 3179,
#  'developed': 865,
#  'manifestation': 1821,
#  'dream': 970,
#  'slip': 2879,
#  'tongue': 3105,
#  'fantasy': 1207,
#  'day': 790,
#  'technique': 3057,
#  'varies': 3224,
#  'relation': 2654,
#  'orientation': 2153,
#  'medical': 1861,
#  'mental': 1881,
#  'professional': 2462,
#  'ha': 1372,
#  'attained': 302,
#  'credential': 747,
#  'satisfactorily': 2773,
#  'completing': 607,
#  'poetry': 2336,
#  'therapy': 3084,
#  'program': 2470,
#  'approved': 254,
#  'national': 1968,
#  'federation': 1214,
#  'biblio/poetry': 369,
#  '(': 6,
#  'nfbpt': 2029,
#  ')': 7,
#  'didactic': 890,
#  'work': 3295,
#  'peer': 2249,
#  'group': 1361,
#  'supervised': 3011,
#  'practicum': 2379,
#  'credentialed': 748,
#  'certified': 483,
#  'therapist': 3083,
#  'cpt': 735,
#  'registered': 2636,
#  'ptr': 2523,
#  'integrates': 1607,
#  'discussion': 928,
#  'published': 2527,
#  'literature': 1766,
#  'reflective': 2619,
#  'creative': 746,
#  'writing': 3305,
#  'psychotherapeutic': 2517,
#  'achieve': 83,
#  'goal': 1343,
#  'well-being': 3281,
#  'reduction': 2609,
#  'improved': 1519,
#  'licensed': 1742,
#  'advanced': 145,
#  'theory': 3080,
#  'practice': 2376,
#  'cpts': 736,
#  'ptrs': 2524,
#  'qualified': 2536,
#  'independently': 1543,
#  'emotionally': 1050,
#  'troubled': 3149,
#  'population': 2346,
#  'rehabilitative': 2646,
#  'community': 592,
#  'educational': 1004,
#  'institution': 1593,
#  'healthy': 1397,
#  'individual': 1548,
#  'adjusting': 123,
#  'issue': 1672,
#  'life': 1746,
#  'crisis': 754,
#  'disability': 915,
#  'completes': 606,
#  'fieldwork': 1225,
#  'commensurate': 584,
#  'highest': 1424,
#  'term': 3066,
#  'facilitation': 1198,
#  'journal': 1682,
#  'bibliotherapy': 370,
#  'poetry/journal': 2337,
#  'reflect': 2617,
#  'interactive': 1621,
#  'use': 3207,
#  'and/or': 223,
#  'promote': 2477,
#  'healing': 1393,
#  'addition': 115,
#  'applies': 244,
#  'form': 1263,
#  'written': 3306,
#  'spoken': 2929,
#  'language': 1711,
#  'including': 1531,
#  'story': 2963,
#  'myth': 1963,
#  'folk': 1253,
#  'fairy': 1204,
#  'tale': 3046,
#  'genre': 1331,
#  'poetic': 2335,
#  'expression': 1173,
#  'memoir': 1877,
#  'narrative': 1966,
#  'thought': 3090,
#  'feeling': 1216,
#  'facilitate': 1195,
#  'participant': 2216,
#  "'": 2,
#  'field': 1224,
#  'encompasses': 1066,
#  'modality': 1916,
#  'duly': 980,
#  'practitioner': 2380,
#  'doctorate': 957,
#  'psychology': 2513,
#  'specialized': 2907,
#  'board': 390,
#  'neuropsychology': 2024,
#  'adheres': 121,
#  'principle': 2439,
#  'focusing': 1252,
#  'primarily': 2435,
#  'neurobehavioral': 2002,
#  'functioning': 1289,
#  'state-issued': 2945,
#  'license': 1741,
#  'provide': 2495,
#  'required': 2688,
#  'assistant': 281,
#  'technician': 3056,
#  'delivers': 822,
#  'consistent': 654,
#  'dimension': 904,
#  'common': 588,
#  'include': 1528,
#  'conducting': 634,
#  'behavioral': 361,
#  'assessment': 276,
#  'analyzing': 214,
#  'data': 789,
#  'revising': 2735,
#  'behavior-analytic': 360,
#  'plan': 2320,
#  'implement': 1511,
#  'component': 615,
#  'overseeing': 2186,
#  'implementation': 1512,
#  'psychologist': 2512,
#  'defined': 811,
#  'observation': 2084,
#  'description': 848,
#  'evaluation': 1134,
#  'interpretation': 1634,
#  'modification': 1919,
#  'human': 1456,
#  'application': 241,
#  'psychological': 2510,
#  'method': 1889,
#  'procedure': 2448,
#  'purpose': 2533,
#  'preventing': 2428,
#  'eliminating': 1042,
#  'symptomatic': 3039,
#  'maladaptive': 1806,
#  'undesired': 3183,
#  'enhancing': 1089,
#  'adjustment': 124,
#  'effectiveness': 1010,
#  'testing': 3076,
#  'characteristic': 494,
#  'intelligence': 1611,
#  'personality': 2280,
#  'ability': 50,
#  'aptitude': 255,
#  'neuropsychological': 2023,
#  'counseling': 721,
#  'psychotherapy': 2518,
#  'hypnosis': 1466,
#  'biofeedback': 377,
#  'diagnosis': 882,
#  'disorder': 931,
#  'alcoholism': 180,
#  'substance': 2989,
#  'abuse': 60,
#  'habit': 1376,
#  'conduct': 632,
#  'aspect': 272,
#  'physical': 2305,
#  'illness': 1490,
#  'accident': 67,
#  'injury': 1578,
#  'psycheducational': 2502,
#  'remediation': 2668,
#  'consultation': 661,
#  'rendered': 2677,
#  'family': 1205,
#  'public': 2526,
#  'distinct': 939,
#  'focus': 1250,
#  'problem': 2445,
#  'special': 2903,
#  'expertise': 1166,
#  '<': 41,
#  'strong': 2977,
#  '>': 42,
#  '/strong': 13,
#  'scientific': 2783,
#  'knowledge': 1699,
#  'interrelationship': 1640,
#  'cognitive': 563,
#  'social': 2882,
#  'biological': 379,
#  'disease': 929,
#  'promotion': 2481,
#  'maintenance': 1801,
#  'prevention': 2429,
#  'rehabilitation': 2645,
#  'improvement': 1520,
#  'care': 448,
#  'dedicated': 804,
#  'development': 867,
#  'regarding': 2630,
#  'interface': 1626,
#  'delivery': 823,
#  'high': 1422,
#  'quality': 2538,
#  'based': 351,
#  'certified/licensed': 484,
#  'independent': 1542,
#  'his/her': 1430,
#  'state': 2944,
#  'experienced': 1163,
#  'direct': 908,
#  'preventative': 2427,
#  'intervention': 1642,
#  'actually': 100,
#  'impaired': 1506,
#  'demonstrably': 826,
#  'risk': 2744,
#  'impairment': 1507,
#  '1974': 18,
#  'completed': 605,
#  'post-doctoral': 2358,
#  'psychopharmacology': 2514,
#  'passed': 2227,
#  'proficiency': 2464,
#  'examination': 1142,
#  'authorized': 319,
#  'statute': 2951,
#  'prescribe': 2415,
#  'medication': 1865,
#  'accordance': 72,
#  'law': 1719,
#  'licensing': 1743,
#  'authority': 317,
#  'management': 1816,
#  'nervous': 1995,
#  'related': 2652,
#  '1': 15,
#  ':': 39,
#  'eliciting': 1036,
#  'patient': 2236,
#  'past': 2229,
#  'role': 2749,
#  'influencing': 1560,
#  'current': 766,
#  'order': 2147,
#  'discover': 923,
#  'mechanism': 1854,
#  'pathologic': 2230,
#  'produced': 2456,
#  'furnish': 1296,
#  'hint': 1427,
#  'employ': 1055,
#  'free': 1278,
#  'association': 288,
#  'recall': 2576,
#  '2': 22,
#  'doctor': 955,
#  'established': 1120,
#  'institute': 1592,
#  'investigation': 1657,
#  'determining': 863,
#  'wa': 3268,
#  'originally': 2156,
#  'conceived': 624,
#  'sigmund': 2860,
#  'freud': 1282,
#  'involves': 1661,
#  'catharsis': 464,
#  'worker': 3296,
#  'person': 2277,
#  'scope': 2790,
#  'provides': 2498,
#  'assistance': 280,
#  'client': 536,
#  'dealing': 795,
#  'environmental': 1103,
#  'hold': 1437,
#  'doctoral': 956,
#  'accredited': 77,
#  'school': 2779,
#  'year': 3310,
#  'post-master': 2363,
#  'setting': 2842,
#  'jurisdiction': 1686,
#  'focused': 1251,
#  'interaction': 1620,
#  'intrapsychic': 1651,
#  'dynamic': 985,
#  'bio-psychosocial': 373,
#  'perspective': 2282,
#  'consist': 653,
#  'client-centered': 538,
#  'advocacy': 150,
#  'disturbance': 946,
#  'appropriately': 251,
#  'requirement': 2689,
#  'regulation': 2642,
#  'standard': 2942,
#  'supervising': 3012,
#  'marriage': 1830,
#  "'s": 5,
#  'substantially': 2992,
#  'equivalent': 1110,
#  'coursework': 729,
#  'receives': 2578,
#  'meet': 1872,
#  'treat': 3143,
#  'context': 670,
#  'couple': 726,
#  'paraprofessional': 2208,
#  'close': 545,
#  'ongoing': 2116,
#  'responsible': 2714,
#  'supervisor': 3014,
#  'collecting': 573,
#  'target': 3048,
#  'certain': 479,
#  'type': 3159,
#  'e.g.': 991,
#  'stimulus': 2957,
#  'preference': 2398,
#  'doe': 962,
#  'design': 849,
#  'assigned': 277,
#  'chiropractic': 511,
#  'd.c.': 780,
#  'medicine': 1867,
#  '-that': 10,
#  'discipline': 921,
#  'art': 264,
#  'deal': 794,
#  'spinal': 2923,
#  'column': 578,
#  'body': 393,
#  'evaluator': 1135,
#  'involved': 1659,
#  'examinee': 1144,
#  'impartially': 1508,
#  'evaluates': 1132,
#  'provided': 2496,
#  'clarify': 530,
#  'liability': 1739,
#  'case': 459,
#  'internist': 1630,
#  'serve': 2835,
#  'primary': 2436,
#  'physician': 2307,
#  'referred': 2613,
#  'co-management': 557,
#  'early': 993,
#  'detection': 859,
#  'functional': 1287,
#  'nutritional': 2078,
#  'pathological': 2231,
#  'utilizes': 3215,
#  'diagnostic': 883,
#  'instrument': 1600,
#  'necessary': 1981,
#  'proper': 2483,
#  'laboratory': 1705,
#  'recognized': 2583,
#  'reference': 2611,
#  'facility': 1199,
#  'manage': 1814,
#  'refer': 2610,
#  'specialist': 2904,
#  'prudent': 2501,
#  'documented': 959,
#  'natural': 1970,
#  'lifestyle': 1750,
#  'change': 491,
#  'resource': 2705,
#  'avoidance': 332,
#  'neurology': 2012,
#  'engages': 1084,
#  'internal': 1628,
#  '-': 9,
#  'external': 1179,
#  'environment': 1102,
#  'structured': 2980,
#  'targeted': 3049,
#  'approach': 249,
#  'affect': 156,
#  'positive': 2352,
#  'consequently': 648,
#  'physiology': 2313,
#  'neurologist': 2011,
#  'board-certified': 391,
#  'non-drug': 2039,
#  'non-surgical': 2051,
#  'neurologically': 2010,
#  'condition': 630,
#  'people': 2252,
#  'suffer': 3003,
#  'broad': 407,
#  'category': 463,
#  'learning': 1728,
#  'attention': 305,
#  'headache': 1392,
#  'vertigo': 3240,
#  'pain': 2195,
#  'syndrome': 3041,
#  'nerve': 1994,
#  'cord': 702,
#  'head': 1391,
#  'stroke': 2975,
#  'movement': 1944,
#  'nutrition': 2077,
#  'profession': 2461,
#  'overall': 2183,
#  'factor': 1201,
#  'maintain': 1797,
#  'manipulative': 1824,
#  'correction': 708,
#  'sustain': 3033,
#  'better': 368,
#  'neurological': 2009,
#  'integrity': 1609,
#  'perform': 2257,
#  'extensive': 1177,
#  'research': 2692,
#  'previous': 2433,
#  'history': 1434,
#  'ethnicity': 1128,
#  'treated': 3144,
#  'questionnaire': 2540,
#  'concerning': 628,
#  'dietary': 892,
#  'sleep': 2878,
#  'pattern': 2241,
#  'present': 2421,
#  'symptomology': 3040,
#  'performed': 2259,
#  'ass': 274,
#  'area': 256,
#  'absorption': 59,
#  'rate': 2567,
#  'adrenal': 141,
#  'function': 1286,
#  'kidney': 1689,
#  'lung': 1790,
#  'instructed': 1597,
#  'check': 499,
#  'ph': 2286,
#  'saliva': 2770,
#  'urine': 3201,
#  'test': 3073,
#  'presence': 2420,
#  'candida': 431,
#  'albicans': 178,
#  'etc.': 1124,
#  'home': 1439,
#  'outside': 2181,
#  'blood': 389,
#  'hair': 1377,
#  'food': 1257,
#  'allergy': 185,
#  'prescription': 2418,
#  'counter': 722,
#  'recorded': 2593,
#  'analyzed': 213,
#  'pediatric': 2245,
#  'chiropractor': 512,
#  'wellness': 3284,
#  'infancy': 1551,
#  'childhood': 509,
#  'adolescence': 139,
#  'newborn': 2028,
#  'adolescent': 140,
#  'radiology': 2556,
#  'referral': 2612,
#  'request': 2685,
#  'radiologist': 2554,
#  'private': 2443,
#  'office': 2105,
#  'hospital': 1446,
#  'teaching': 3053,
#  'need': 1984,
#  'referring': 2614,
#  'consultative': 663,
#  'reflected': 2618,
#  'recommend': 2585,
#  'supervise': 3010,
#  'interpret': 1633,
#  'radiologic': 2552,
#  'study': 2982,
#  'imaging': 1492,
#  'advise': 147,
#  'necessity': 1982,
#  'appropriateness': 252,
#  'select': 2811,
#  'avoid': 331,
#  'instance': 1590,
#  'act': 93,
#  'apply': 245,
#  'called': 426,
#  'expert': 1165,
#  'witness': 3293,
#  'matter': 1837,
#  'litigation': 1768,
#  'concerned': 627,
#  'technology': 3060,
#  'image': 1491,
#  'production': 2459,
#  'demonstration': 829,
#  'normal': 2064,
#  'abnormal': 53,
#  'anatomy': 220,
#  'energy': 1079,
#  'advance': 144,
#  'technological': 3058,
#  'facet': 1193,
#  'rapid': 2566,
#  'reasonably': 2574,
#  'expected': 1161,
#  'continuously': 677,
#  'plain': 2319,
#  'film': 1227,
#  'radiography': 2549,
#  'fluoroscopy': 1249,
#  'tomography': 3104,
#  'ultrasonography': 3168,
#  'radioisotope': 2550,
#  'computed': 623,
#  'digital': 902,
#  'magnetic': 1794,
#  'resonance': 2704,
#  'vary': 3227,
#  'intent': 1616,
#  'restoring': 2718,
#  'pre-injury': 2387,
#  'pre-disease': 2385,
#  'status': 2950,
#  'activity': 98,
#  'daily': 785,
#  'sport': 2931,
#  'recreational': 2598,
#  'participates': 2218,
#  'relevant': 2658,
#  'e.g': 990,
#  'strength': 2970,
#  'endurance': 1078,
#  'flexibility': 1241,
#  'motor': 1942,
#  'control': 689,
#  'intermediate': 1627,
#  'final': 1228,
#  'successful': 2999,
#  'return': 2730,
#  'participation': 2220,
#  'onset': 2117,
#  'essential': 1117,
#  'patient-centered': 2237,
#  'outcome': 2177,
#  'independence': 1541,
#  'self-management': 2823,
#  'self-care': 2820,
#  'skill': 2874,
#  'uniquely': 3187,
#  'resulting': 2723,
#  'fitness': 1235,
#  'diplomate': 907,
#  'american': 205,
#  'dacbsp': 784,
#  'ccsp': 471,
#  'extremity': 1185,
#  'soft': 2888,
#  'tissue': 3099,
#  'utilized': 3214,
#  'cover': 731,
#  'spectrum': 2918,
#  'athlete': 296,
#  'olympic': 2108,
#  'using': 3210,
#  'variety': 3225,
#  'occupational': 2096,
#  'considers': 652,
#  'assist': 279,
#  'federal': 1212,
#  'compliance': 611,
#  'farther': 1209,
#  'simply': 2866,
#  'treating': 3145,
#  'injured': 1577,
#  'mean': 1848,
#  'working': 3297,
#  'optimum': 2139,
#  'safety': 2767,
#  'ergonomic': 1112,
#  'interacting': 1619,
#  'prevent': 2426,
#  'future': 1304,
#  'assisting': 283,
#  'company': 595,
#  'identify': 1483,
#  'root': 2751,
#  'cause': 466,
#  'redesigning': 2604,
#  'workstation': 3300,
#  'eliminate': 1041,
#  'hazard': 1387,
#  'team': 3054,
#  'providing': 2499,
#  'list': 1765,
#  'potential': 2371,
#  'interact': 1618,
#  'lengthy': 1734,
#  'varied': 3223,
#  'involving': 1662,
#  'site': 2870,
#  'orthopedics': 2160,
#  'branch': 399,
#  'continued': 673,
#  'acquisition': 92,
#  'relative': 2656,
#  'relate': 2651,
#  'bone': 394,
#  'joint': 1681,
#  'capsule': 439,
#  'disc': 919,
#  'muscle': 1954,
#  'ligament': 1751,
#  'tendon': 3065,
#  'complete': 604,
#  'vascular': 3228,
#  'organ': 2148,
#  'contiguous': 671,
#  'perfection': 2256,
#  'exists': 1158,
#  'historical': 1432,
#  'review': 2732,
#  'correlative': 711,
#  'bound': 395,
#  'combined': 581,
#  'basis': 353,
#  'desire': 855,
#  'eventual': 1137,
#  'remission': 2670,
#  'resolution': 2702,
#  'readily': 2573,
#  'achievable': 82,
#  'orthopedist': 2161,
#  'seeking': 2805,
#  'engage': 1081,
#  'subject': 2986,
#  'material': 1836,
#  'pursuing': 2534,
#  'quest': 2539,
#  'changing': 492,
#  'orthopedic': 2159,
#  'dentist': 832,
#  'dental': 831,
#  'surgery': 3024,
#  'd.d.s': 781,
#  'd.m.d': 782,
#  'dentistry': 833,
#  'practicing': 2378,
#  'difference': 896,
#  'dmd': 954,
#  'dd': 791,
#  'university': 3190,
#  'prerogative': 2414,
#  'determine': 861,
#  'awarded': 334,
#  'curriculum': 768,
#  'set': 2841,
#  'commission': 586,
#  'accreditation': 76,
#  'generally': 1324,
#  'undergraduate': 3176,
#  'plus': 2331,
#  'graduate': 1350,
#  'general': 1322,
#  'accept': 62,
#  'allow': 188,
#  'additional': 116,
#  'post-graduate': 2359,
#  'science': 2782,
#  'controlling': 691,
#  'promoting': 2480,
#  'organized': 2151,
#  'effort': 1013,
#  'serf': 2832,
#  'administration': 131,
#  'successfully': 3000,
#  'postdoctoral': 2367,
#  'anesthesiology': 227,
#  'residency': 2695,
#  'duration': 982,
#  'accord': 71,
#  'eligibility': 1038,
#  'morphology': 1938,
#  'pathology': 2233,
#  'pulp': 2530,
#  'periradicular': 2270,
#  'encompass': 1065,
#  'basic': 352,
#  'biology': 381,
#  'etiology': 1129,
#  'associated': 287,
#  'age': 161,
#  'coordination': 697,
#  'oral': 2144,
#  'nature': 1972,
#  'identification': 1480,
#  'affecting': 158,
#  'maxillofacial': 1840,
#  'region': 2633,
#  'investigates': 1655,
#  'effect': 1007,
#  'radiographic': 2548,
#  'microscopic': 1897,
#  'biochemical': 374,
#  'age-defined': 162,
#  'preventive': 2432,
#  'infant': 1552,
#  'child': 506,
#  'supporting': 3020,
#  'surrounding': 3027,
#  'teeth': 3061,
#  'substitute': 2994,
#  'esthetic': 1121,
#  'structure': 2979,
#  'pertaining': 2283,
#  'restoration': 2716,
#  'comfort': 583,
#  'appearance': 238,
#  'replacement': 2680,
#  'missing': 1913,
#  'artificial': 270,
#  'surgical': 3025,
#  'adjunctive': 122,
#  'defect': 807,
#  'hard': 1384,
#  'radiant': 2542,
#  'used': 3208,
#  'guidance': 1368,
#  'growing': 1364,
#  'mature': 1839,
#  'dentofacial': 835,
#  'require': 2687,
#  'malrelationships': 1813,
#  'malformation': 1807,
#  'facial': 1194,
#  'force': 1260,
#  'stimulation': 2956,
#  'redirection': 2606,
#  'craniofacial': 739,
#  'complex': 609,
#  'major': 1802,
#  'responsibility': 2713,
#  'orthodontic': 2157,
#  'interception': 1622,
#  'malocclusion': 1811,
#  'alteration': 190,
#  'corrective': 709,
#  'appliance': 239,
#  'dentition': 834,
#  'attain': 301,
#  'occlusal': 2094,
#  'physiologic': 2309,
#  'harmony': 1385,
#  'cranial': 738,
#  'definition': 812,
#  'come': 582,
#  'hygiene': 1460,
#  'examiner': 1145,
#  'legally': 1731,
#  'delegated': 819,
#  'hygienist': 1462,
#  'preparation': 2407,
#  'minimum': 1907,
#  'scaling': 2774,
#  'polishing': 2342,
#  'misleading': 1912,
#  'title': 3100,
#  'auxiliary': 327,
#  'non-accredited': 2033,
#  'tribal': 3147,
#  'entity': 1099,
#  'br/': 397,
#  'prepared': 2410,
#  'interdependent': 1623,
#  'decision': 799,
#  'making': 1805,
#  'accountability': 74,
#  'judgment': 1683,
#  'continuum.': 679,
#  'remote': 2671,
#  'specializing': 2909,
#  'systemic': 3043,
#  'medicinist': 1869,
#  'manages': 1818,
#  'non-dental': 2036,
#  'cancer': 429,
#  'transplant': 3132,
#  'acute': 104,
#  'chronic': 518,
#  'provision': 2500,
#  'interdisciplinary': 1624,
#  'collaboration': 568,
#  'outpatient': 2179,
#  'clinic': 539,
#  'requiring': 2691,
#  'multidisciplinary': 1950,
#  'healthcare': 1396,
#  'aid': 169,
#  'performs': 2261,
#  'nonclinical': 2055,
#  'duty': 983,
#  'fabrication': 1191,
#  'prosthesis': 2487,
#  'device': 872,
#  'authorization': 318,
#  'appropriate': 250,
#  'manager': 1817,
#  'charged': 497,
#  'maintaining': 1799,
#  'cost/profit': 717,
#  'objective': 2083,
#  'purchasing': 2532,
#  'department': 837,
#  'staff..': 2939,
#  'understand': 3178,
#  'partnership': 2223,
#  'dietitian': 895,
#  'offer': 2102,
#  'cdm': 472,
#  'designation': 852,
#  'specific': 2912,
#  'course': 728,
#  'credentialing': 749,
#  'exam': 1141,
#  'sanitation': 2772,
#  'adapting': 110,
#  'applying': 246,
#  'nutrient': 2076,
#  'solution': 2891,
#  'nutritionist': 2079,
#  'instruct': 1596,
#  'developing': 866,
#  'meal': 1846,
#  'necessarily': 1980,
#  'meeting': 1873,
#  'academic': 61,
#  'qualify': 2537,
#  'dietician': 894,
#  'rd': 2569,
#  'bachelor': 339,
#  'u': 3162,
#  'regionally': 2635,
#  'college': 576,
#  'dietetic': 893,
#  'ada': 106,
#  'ada-accredited': 107,
#  'typically': 3161,
#  '6': 37,
#  '12': 16,
#  'month': 1934,
#  'length': 1733,
#  'administered': 128,
#  'registration': 2637,
#  'continuing': 675,
#  'integral': 1605,
#  'foodservice': 1258,
#  'dtr': 978,
#  'two-year': 3157,
#  'associate': 286,
#  '450': 33,
#  'hour': 1452,
#  'specially': 2910,
#  'living': 1771,
#  'urgent/emergent': 3198,
#  'situation': 2871,
#  'able': 52,
#  'cpr': 734,
#  'sufficient': 3005,
#  'allay': 182,
#  'fear': 1210,
#  'resolve': 2703,
#  'transportation': 3135,
#  'various': 3226,
#  'business': 422,
#  'contacting': 667,
#  'agency': 164,
#  'initiate': 1573,
#  'reassurance': 2575,
#  'emt': 1060,
#  'paramedic': 2203,
#  'support': 3018,
#  'al': 177,
#  'emergency': 1047,
#  'optometry': 2143,
#  'od': 2101,
#  'eye': 1186,
#  'optometrist': 2142,
#  'examine': 1143,
#  'diagnose': 879,
#  'visual': 3256,
#  'pre-professional': 2388,
#  'leading': 1725,
#  'o.d': 2081,
#  'optional': 2141,
#  'state-licensed': 2946,
#  'fitting': 1237,
#  'contact': 666,
#  'lens': 1735,
#  ...}

# %%
tfidfvectorizer.shape
# Out:
# (854, 3317)

# %%
type(tfidfvectorizer)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
tfidfvect.get_feature_names()
# Out:
# ['%',
#  '&',
#  "'",
#  "''",
#  "'hospitalist",
#  "'s",
#  '(',
#  ')',
#  ',',
#  '-',
#  '-that',
#  '.',
#  '/',
#  '/strong',
#  '0',
#  '1',
#  '12',
#  '1603',
#  '1974',
#  '1988',
#  '1993',
#  '1996',
#  '2',
#  '20',
#  '200',
#  '21',
#  '24',
#  '24-hour',
#  '25',
#  '282j00000x',
#  '3',
#  '4',
#  '42',
#  '450',
#  '493.1405',
#  '5',
#  '50',
#  '6',
#  '797-compliant',
#  ':',
#  ';',
#  '<',
#  '>',
#  '[',
#  ']',
#  '``',
#  'a.d.n',
#  'a10',
#  'abdomen',
#  'abdominal',
#  'ability',
#  'ablation',
#  'able',
#  'abnormal',
#  'abnormality',
#  'abortion',
#  'abortion/family',
#  'absence',
#  'absent',
#  'absorption',
#  'abuse',
#  'academic',
#  'accept',
#  'acceptance',
#  'access',
#  'accessible',
#  'accessing',
#  'accident',
#  'accommodate',
#  'accommodation',
#  'accomplished',
#  'accord',
#  'accordance',
#  'according',
#  'accountability',
#  'accountable',
#  'accreditation',
#  'accredited',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'acetabular',
#  'achievable',
#  'achieve',
#  'achievement',
#  'acms',
#  'acms-approved',
#  'acnm',
#  'acote',
#  'acquire',
#  'acquired',
#  'acquiring',
#  'acquisition',
#  'act',
#  'acting',
#  'action',
#  'activation',
#  'active',
#  'activity',
#  'actual',
#  'actually',
#  'acupuncture',
#  'acupuncturist',
#  'acupuncturists',
#  'acute',
#  'acutely',
#  'ada',
#  'ada-accredited',
#  'adaptation',
#  'adapted',
#  'adapting',
#  'adaptive',
#  'added',
#  'addiction',
#  'addiction-focused',
#  'addition',
#  'additional',
#  'additionally',
#  'address',
#  'addressing',
#  'adequate',
#  'adheres',
#  'adjunctive',
#  'adjusting',
#  'adjustment',
#  'adl',
#  'adls',
#  'administer',
#  'administered',
#  'administering',
#  'administers',
#  'administration',
#  'administrative',
#  'administrator',
#  'admission',
#  'admit',
#  'admitted',
#  'admitting',
#  'adnexa',
#  'adolescence',
#  'adolescent',
#  'adrenal',
#  'adult',
#  'adulthood',
#  'advance',
#  'advanced',
#  'adverse',
#  'advise',
#  'advised',
#  'advisor',
#  'advocacy',
#  'advocate',
#  'aerodigestive',
#  'aerospace',
#  'aesthetic',
#  'affair',
#  'affect',
#  'affected',
#  'affecting',
#  'affiliated',
#  'afs-900',
#  'age',
#  'age-defined',
#  'aged',
#  'agency',
#  'agent',
#  'aging',
#  'agreement',
#  'aha',
#  'aid',
#  'aide',
#  'aim',
#  'aimed',
#  'air',
#  'aircraft',
#  'airplane',
#  'airway',
#  'al',
#  'albicans',
#  'alcohol',
#  'alcoholism',
#  'alimentary',
#  'allay',
#  'allergic',
#  'allergist-immunologist',
#  'allergy',
#  'alleviation',
#  'allied',
#  'allow',
#  'allows',
#  'alteration',
#  'altered',
#  'alternate',
#  'alternating',
#  'alternative',
#  'alternatively',
#  'alzheimer',
#  'ama',
#  'amblyopia',
#  'ambulance',
#  'ambulation',
#  'ambulatory',
#  'ameliorate',
#  'amendment',
#  'america',
#  'american',
#  'amplification',
#  'amyotrophic',
#  'anal',
#  'analysand',
#  'analysis',
#  'analyst',
#  'analyze',
#  'analyzed',
#  'analyzing',
#  'anaphylaxis',
#  'anaplastologist',
#  'anaplastologists',
#  'anaplastology',
#  'anatomic',
#  'anatomy',
#  'ancient',
#  'ancillary',
#  'and/or',
#  'anemia',
#  'anesthesia',
#  'anesthesiologist',
#  'anesthesiology',
#  'anesthetist',
#  'ankle',
#  'annual',
#  'anomaly',
#  'anterior',
#  'antibiotic',
#  'antibody',
#  'antimicrobial',
#  'anxiety',
#  'apart',
#  'appearance',
#  'appliance',
#  'applicable',
#  'application',
#  'application/adjustment/removal',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appraisal',
#  'apprenticeship',
#  'approach',
#  'appropriate',
#  'appropriately',
#  'appropriateness',
#  'approval',
#  'approved',
#  'aptitude',
#  'area',
#  'arise',
#  'arising',
#  'armed',
#  'arrange',
#  'arrangement',
#  'array',
#  'arrt',
#  'art',
#  'arterial',
#  'artery',
#  'arthritis',
#  'arthroplasty',
#  'arthroscopy',
#  'artificial',
#  'aseptic',
#  'aspect',
#  'aspiration',
#  'ass',
#  'assessing',
#  'assessment',
#  'assigned',
#  'assimilable',
#  'assist',
#  'assistance',
#  'assistant',
#  'assisted',
#  'assisting',
#  'assistive',
#  'assoc',
#  'associate',
#  'associated',
#  'association',
#  'assumed',
#  'assumes',
#  'assurance',
#  'assure',
#  'assuring',
#  'asthma',
#  'athe',
#  'athlete',
#  'athletic',
#  'atmospheric',
#  'atom',
#  'attack',
#  'attain',
#  'attained',
#  'attainment',
#  'attend',
#  'attention',
#  'atypical',
#  'audiological',
#  'audiologist',
#  'audiologist-hearing',
#  'audiologist/hearing',
#  'audiologists',
#  'audiology',
#  'audiotry',
#  'auditory',
#  'augmentative',
#  'aural',
#  'authority',
#  'authorization',
#  'authorized',
#  'autism',
#  'autoimmune',
#  'autonomic',
#  'autonomous',
#  'autonomy',
#  'autopsy',
#  'autotransfusion',
#  'auxiliary',
#  'availability',
#  'available',
#  'aviation',
#  'avoid',
#  'avoidance',
#  'award',
#  'awarded',
#  'away',
#  'b',
#  'b.s.n',
#  'baccalaureate',
#  'bachelor',
#  'back-up',
#  'background',
#  'bacteria',
#  'bacteriological',
#  'bacteriology',
#  'balance',
#  'bank',
#  'banking',
#  'banking/transfusion',
#  'bariatric',
#  'base',
#  'based',
#  'basic',
#  'basis',
#  'bathing',
#  'bcca',
#  'bed',
#  'bedside',
#  'begin',
#  'behavior',
#  'behavior-analytic',
#  'behavioral',
#  'belief',
#  'belong',
#  'beneficiary',
#  'benefit',
#  'benign',
#  'best',
#  'better',
#  'biblio/poetry',
#  'bibliotherapy',
#  'bifida',
#  'biliary',
#  'bio-psychosocial',
#  'biochemical',
#  'biochemistry',
#  'bioethics',
#  'biofeedback',
#  'biologic',
#  'biological',
#  'biologics',
#  'biology',
#  'biomechanical',
#  'biomechanics',
#  'biophysical',
#  'birth',
#  'bite',
#  'bladder',
#  'bleeding',
#  'blood',
#  'board',
#  'board-certified',
#  'bodily',
#  'body',
#  'bone',
#  'bound',
#  'bowel',
#  'br/',
#  'brain',
#  'branch',
#  'breadth',
#  'breast',
#  'breastfeeding',
#  'breathing',
#  'bridge',
#  'bridgework',
#  'bring',
#  'broad',
#  'broadened',
#  'broadly',
#  'brochure',
#  'broken',
#  'brokerage',
#  'bronchitis',
#  'bronchopulmonary',
#  'brow',
#  'build',
#  'building',
#  'burden',
#  'burial',
#  'burn',
#  'bus',
#  'business',
#  'caahep',
#  'calculated',
#  'calibrate',
#  'called',
#  'camping',
#  'canal',
#  'cancer',
#  'cancerous',
#  'candida',
#  'candidate',
#  'cane',
#  'capability',
#  'capable',
#  'capacity',
#  'capitated',
#  'capitation',
#  'capsule',
#  'carbon',
#  'cardiac',
#  'cardiologist',
#  'cardiology',
#  'cardiopulmonary',
#  'cardiothoracic',
#  'cardiovascular',
#  'cardiovascular/peripheral',
#  'care',
#  'cared',
#  'career',
#  'caregiver',
#  'caretaker/guardian',
#  'caring',
#  'carotid',
#  'carpal',
#  'carrier',
#  'carry',
#  'carrying',
#  'case',
#  'cast',
#  'casting',
#  'cataract',
#  'category',
#  'catharsis',
#  'catheter',
#  'cause',
#  'caused',
#  'cauterizing',
#  'cbrpa',
#  'cca',
#  'ccsp',
#  'cdm',
#  'cell',
#  'cellular',
#  'center',
#  'central',
#  'cerebral',
#  'cerebrospinal',
#  'certain',
#  'certificate',
#  'certificate-holding',
#  'certification',
#  'certified',
#  'certified/licensed',
#  'cervical',
#  'cessation',
#  'cfr',
#  'cgp',
#  'challenge',
#  'chamber',
#  'change',
#  'changing',
#  'chapter',
#  'characteristic',
#  'characterize',
#  'characterized',
#  'charged',
#  'chdo',
#  'check',
#  'chemical',
#  'chemistry',
#  'chemotherapeutic',
#  'chemotherapy',
#  'chest',
#  'chiefly',
#  'child',
#  'childbearing',
#  'childbirth',
#  'childhood',
#  'childhood-onset',
#  'chiropractic',
#  'chiropractor',
#  'choice',
#  'choose',
#  'chore',
#  'chosen',
#  'chromosome',
#  'chronic',
#  'chronically',
#  'chw',
#  'chws',
#  'circadian',
#  'circulation',
#  'circulatory',
#  'circumstance',
#  'city',
#  'civil',
#  'civilian',
#  'clamping',
#  'clarify',
#  'class',
#  'classification',
#  'classified',
#  'clear',
#  'clearance',
#  'client',
#  'client-care',
#  'client-centered',
#  'clinic',
#  'clinic/center',
#  'clinical',
#  'clinically',
#  'clinician-patient',
#  'clinician/clinical',
#  'close',
#  'closely',
#  'closure',
#  'clot',
#  'clothes',
#  'clotting',
#  'club',
#  'cm',
#  'cme',
#  'cmops',
#  'cnm',
#  'cnms',
#  'co-management',
#  'coach-player',
#  'coast',
#  'code',
#  'coding',
#  'cognition',
#  'cognitive',
#  'cognitively',
#  'cold',
#  'collaborate',
#  'collaborating',
#  'collaboration',
#  'collaborative',
#  'collagen',
#  'colleague',
#  'collect',
#  'collecting',
#  'collection',
#  'collective',
#  'college',
#  'colon',
#  'column',
#  'combination',
#  'combine',
#  'combined',
#  'come',
#  'comfort',
#  'commensurate',
#  'commercial',
#  'commission',
#  'committee',
#  'common',
#  'commonly',
#  'commonplace',
#  'communication',
#  'community',
#  'companion',
#  'companionship',
#  'company',
#  'compared',
#  'compatibility',
#  'compatible',
#  'compensate',
#  'compensatory',
#  'competence',
#  'competency',
#  'complementary',
#  'complete',
#  'completed',
#  'completes',
#  'completing',
#  'completion',
#  'complex',
#  'complexity',
#  'compliance',
#  'complicated',
#  'complication',
#  'complies',
#  'component',
#  'compound',
#  'compounding',
#  'comprehension',
#  'comprehensive',
#  'compression',
#  'compromise',
#  'compromised',
#  'computed',
#  'conceived',
#  'concentrate',
#  'concept',
#  'concerned',
#  'concerning',
#  'concurrent',
#  'condition',
#  'conditioning',
#  'conduct',
#  'conducted',
#  'conducting',
#  'conduction',
#  'conference',
#  'confirm',
#  'confirmation',
#  'conflict',
#  'conform',
#  'congenital',
#  'congregate',
#  'conjoint',
#  'conjunction',
#  'conjunctiva',
#  'connective',
#  'consequence',
#  'consequently',
#  'consider',
#  'consideration',
#  'considered',
#  'considers',
#  'consist',
#  'consistent',
#  'consists',
#  'consolidated',
#  'constituent',
#  'constituted',
#  'construction',
#  'consultant',
#  'consultation',
#  'consultation-liaison',
#  'consultative',
#  'consulting',
#  'consults',
#  'contact',
#  'contacting',
#  'contained',
#  'containing',
#  'context',
#  'contiguous',
#  'continue',
#  'continued',
#  'continues',
#  'continuing',
#  'continuous',
#  'continuously',
#  'continuum',
#  'continuum.',
#  'contraceptive',
#  'contract',
#  'contracted',
#  'contracting',
#  'contractor',
#  'contrast',
#  'contribute',
#  'contributes',
#  'contribution',
#  'control',
#  'controlled',
#  'controlling',
#  'conveyance',
#  'cooperation',
#  'coordinate',
#  'coordinated',
#  'coordinating',
#  'coordination',
#  'copayment',
#  'copd',
#  'cope',
#  'coping',
#  'cord',
#  'cornea',
#  'corneal',
#  'coronary',
#  'coroner',
#  'corpsman',
#  'correction',
#  'corrective',
#  'correlation',
#  'correlative',
#  'correspondence',
#  'cosmesis',
#  'cosmetic',
#  'cost',
#  'cost-effective',
#  'cost/profit',
#  'costly',
#  'council',
#  'counsel',
#  'counseling',
#  'counter',
#  'countermeasure',
#  'countertransference',
#  'county',
#  'couple',
#  'coupled',
#  'course',
#  'coursework',
#  'court',
#  'cover',
#  'coverage',
#  'covered',
#  'cpr',
#  'cpt',
#  'cpts',
#  'craft',
#  'cranial',
#  'craniofacial',
#  'craniomaxillofacial',
#  'cranium',
#  'created',
#  'creates',
#  'creating',
#  'creation',
#  'creative',
#  'credential',
#  'credentialed',
#  'credentialing',
#  'cremation',
#  'crewmembers',
#  'crime',
#  'criminal',
#  'crisis',
#  'critical',
#  'critically',
#  'critically-ill',
#  'cross',
#  'crown',
#  'crt',
#  'crutch',
#  'cryosurgery',
#  'ct',
#  'cuing',
#  'culturally',
#  'current',
#  'currently',
#  'curriculum',
#  'custodial',
#  'custom',
#  'customization',
#  'customize',
#  'cutaneous',
#  'cycle',
#  'cyst',
#  'cytogeneticist',
#  'cytological',
#  'cytology',
#  'cytopathologist',
#  'd.c.',
#  'd.d.s',
#  'd.m.d',
#  'd.p.m',
#  'dacbsp',
#  'daily',
#  'damage',
#  'damaged',
#  'dance',
#  'data',
#  'day',
#  'dd',
#  'dea',
#  'dead',
#  'deal',
#  'dealing',
#  'death',
#  'decentralized',
#  'decides',
#  'decision',
#  'decision-making',
#  'decompression',
#  'decrease',
#  'decremental',
#  'dedicated',
#  'deductible',
#  'deemed',
#  'defect',
#  'defective',
#  'defense',
#  'deficiency',
#  'defined',
#  'definition',
#  'deformation',
#  'deformity',
#  'degenerative',
#  'degree',
#  'delay',
#  'delayed',
#  'delegated',
#  'deliver',
#  'delivered',
#  'delivers',
#  'delivery',
#  'demand',
#  'dementia',
#  'demonstrably',
#  'demonstrated',
#  'demonstrates',
#  'demonstration',
#  'densitometry',
#  'dental',
#  'dentist',
#  'dentistry',
#  'dentition',
#  'dentofacial',
#  'denture',
#  'department',
#  'department/certification/licensing',
#  'depending',
#  'deployed',
#  'derived',
#  'dermatitis',
#  'dermatologist',
#  'dermatology',
#  'dermatopathologist',
#  'dermatopathology',
#  'described',
#  'description',
#  'design',
#  'designated',
#  'designates',
#  'designation',
#  'designed',
#  'designing',
#  'desire',
#  'desired',
#  'destructive',
#  'detect',
#  'detection',
#  'determination',
#  'determine',
#  'determined',
#  'determining',
#  'develop',
#  'developed',
#  'developing',
#  'development',
#  'developmental',
#  'developmental-behavioral',
#  'developmentally',
#  'develops',
#  'device',
#  'devise',
#  'devoted',
#  'devotes',
#  'dhp',
#  'diabetes',
#  'diabetic',
#  'diagnose',
#  'diagnosed',
#  'diagnosing',
#  'diagnosis',
#  'diagnostic',
#  'diagnostics',
#  'dialysis',
#  'diaper',
#  'diaphragm',
#  'diarrhea',
#  'diathermy',
#  'didactic',
#  'diet',
#  'dietary',
#  'dietetic',
#  'dietician',
#  'dietitian',
#  'difference',
#  'different',
#  'differentiated',
#  'differs',
#  'difficulty',
#  'digestive',
#  'digital',
#  'dilemma',
#  'dimension',
#  'diminution',
#  'diploma',
#  'diplomate',
#  'direct',
#  'directed',
#  'directing',
#  'direction',
#  'directly',
#  'director',
#  'directs',
#  'disability',
#  'disabled',
#  'disabling',
#  'disaster',
#  'disc',
#  'discharge',
#  'discipline',
#  'discourage',
#  'discover',
#  'discovery',
#  'discrete',
#  'discriminate',
#  'discussing',
#  'discussion',
#  'disease',
#  'diseased',
#  'disorder',
#  'disordered',
#  'dispense',
#  'dispensed',
#  'dispenses',
#  'dispensing',
#  'disposition',
#  'distance',
#  'distinct',
#  'distinction',
#  'distressing',
#  'distribute',
#  'distributes',
#  'distribution',
#  'district',
#  'disturbance',
#  'disturbed',
#  'diver',
#  'diverse',
#  'diversified',
#  'diving',
#  'division',
#  'dizziness',
#  'dmd',
#  'doctor',
#  'doctoral',
#  'doctorate',
#  'document',
#  'documented',
#  'documenting',
#  'dod',
#  'doe',
#  'doing',
#  'domain',
#  'donated',
#  'donor',
#  'dos',
#  'doula',
#  'drainage',
#  'dream',
#  'dressing',
#  'drive',
#  'driver',
#  'driving',
#  'drug',
#  'drug-induced',
#  'drug-related',
#  'dtr',
#  'dual',
#  'duly',
#  'duplex',
#  'duration',
#  'duty',
#  'dying',
#  'dynamic',
#  'dysfunction',
#  'dysphagia',
#  'dyspnea',
#  'dystrophy',
#  'e.g',
#  'e.g.',
#  'ear',
#  'early',
#  'earth',
#  'ease',
#  'eating',
#  'economic',
#  'eczema',
#  'edition',
#  ...]
